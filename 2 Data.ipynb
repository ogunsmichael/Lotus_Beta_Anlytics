# %% [markdown]
# # Data Exploration with Pandas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/titanic-train.csv')

# %%
#Checking the Data Type 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Indexing

# %%
#INTEGER LOCATION == ILOC
pd.DataFrame(df.iloc[3])
# Out:
#                                                         3
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                    35
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S

# %%
#location by name string name
df.loc[0:4,'Ticket']
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df['Ticket'].head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df[['Embarked', 'Ticket']].head()
# Out:
#   Embarked            Ticket
# 0        S         A/5 21171
# 1        C          PC 17599
# 2        S  STON/O2. 3101282
# 3        S            113803
# 4        S            373450

# %% [markdown]
# ### Selections

# %%
df[df['Age'] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df['Age'] > 70
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.query("Age > 70")
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[(df['Age'] == 11) & (df['SibSp'] == 5)]
# Out:
#     PassengerId  Survived  Pclass                                Name   Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9   NaN        S

# %%
df[(df.Age == 11) | (df.SibSp == 5)]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %%
df.query('(Age == 11) | (SibSp == 5)')
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %% [markdown]
# ### Unique Values

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ### Sorting

# %%
df.sort_values('Age', ascending = False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %% [markdown]
# ### Aggregations

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby(['Pclass', 'Survived'])['PassengerId'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
mean_age_by_survived = df.groupby('Survived')['Age'].mean()
mean_age_by_survived
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
std_age_by_survived = df.groupby('Survived')['Age'].std()
std_age_by_survived
# Out:
# Survived
# 0    14.172110
# 1    14.950952
# Name: Age, dtype: float64

# %% [markdown]
# ### Merge

# %%
df1 = mean_age_by_survived.round(0).reset_index()
df2 = std_age_by_survived.round(0).reset_index()

# %%
df1
# Out:
#    Survived   Age
# 0         0  31.0
# 1         1  28.0

# %%
df2
# Out:
#    Survived   Age
# 0         0  14.0
# 1         1  15.0

# %%
df3 = pd.merge(df1, df2, on='Survived')

# %%
df3
# Out:
#    Survived  Age_x  Age_y
# 0         0   31.0   14.0
# 1         1   28.0   15.0

# %%
df3.columns = ['Survived', 'Average Age', 'Age Standard Deviation']

# %%
df3
# Out:
#    Survived  Average Age  Age Standard Deviation
# 0         0         31.0                    14.0
# 1         1         28.0                    15.0

# %% [markdown]
# ### Pivot Tables

# %%
df.pivot_table(index='Pclass',
               columns='Survived',
               values='PassengerId',
               aggfunc='count')
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %% [markdown]
# ### Correlations

# %%
df['IsFemale'] = df['Sex'] == 'female'

# %%
correlated_with_survived = df.corr()['Survived'].sort_values()
correlated_with_survived
# Out:
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# PassengerId   -0.005007
# Parch          0.081629
# Fare           0.257307
# IsFemale       0.543351
# Survived       1.000000
# Name: Survived, dtype: float64

# %%
# %matplotlib inline

# %%
correlated_with_survived.iloc[:-1].plot(kind='bar',
                                        title='Titanic Passengers: correlation with survival')

# %% [markdown]
# # Visual Data Exploration with Matplotlib

# %%
data1 = np.random.normal(0, 0.1, 1000)
data2 = np.random.normal(1, 0.4, 1000) + np.linspace(0, 1, 1000)
data3 = 2 + np.random.random(1000) * np.linspace(1, 5, 1000)
data4 = np.random.normal(3, 0.2, 1000) + 0.3 * np.sin(np.linspace(0, 20, 1000))

# %%
data = np.vstack([data1, data2, data3, data4]).transpose()

# %%
df = pd.DataFrame(data, columns=['data1', 'data2', 'data3', 'data4'])
df.head()
# Out:
#       data1     data2     data3     data4
# 0 -0.044649  0.412695  2.139747  2.737325
# 1  0.207547  1.365115  2.915701  3.088111
# 2 -0.032189  0.778834  2.179364  2.738091
# 3  0.052476  0.336745  2.967987  3.043054
# 4  0.015791  0.783849  2.343101  3.237619

# %% [markdown]
# ### Line Plot

# %%
df.plot(title='Line plot')

# %%
plt.plot(df)
plt.title('Line plot')
plt.legend(['data1', 'data2', 'data3', 'data4'])

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(style='.')

# %%
_ = df.plot(kind='scatter', x='data1', y='data2',
            xlim=(-1.5, 1.5), ylim=(0, 3))

# %% [markdown]
# ### Histograms

# %%
df.plot(kind='hist',
        bins=50,
        title='Histogram',
        alpha=0.6)

# %% [markdown]
# ### Cumulative distribution

# %%
df.plot(kind='hist',
        bins=100,
        title='Cumulative distributions',
        normed=True,
        cumulative=True,
        alpha=0.4)
# Out:
# C:\Users\LBAN\anaconda3\envs\ztdl\lib\site-packages\pandas\plotting\_core.py:1344: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %% [markdown]
# ### Box Plot

# %%
df.plot(kind='box',
        title='Boxplot')

# %% [markdown]
# ### Subplots

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 5))

df.plot(ax=ax[0][0],
        title='Line plot')

df.plot(ax=ax[0][1],
        style='o',
        title='Scatter plot')

df.plot(ax=ax[1][0],
        kind='hist',
        bins=50,
        title='Histogram')

df.plot(ax=ax[1][1],
        kind='box',
        title='Boxplot')

plt.tight_layout()

# %% [markdown]
# ### Pie charts

# %%
gt01 = df['data1'] > 0.1
piecounts = gt01.value_counts()
piecounts
# Out:
# False    846
# True     154
# Name: data1, dtype: int64

# %%
piecounts.plot(kind='pie',
               figsize=(5, 5),
               explode=[0, 0.15],
               labels=['<= 0.1', '> 0.1'],
               autopct='%1.1f%%',
               shadow=True,
               startangle=90,
               fontsize=16)

# %% [markdown]
# ### Hexbin plot

# %%
data = np.vstack([np.random.normal((0, 0), 2, size=(1000, 2)),
                  np.random.normal((9, 9), 3, size=(2000, 2))])
df = pd.DataFrame(data, columns=['x', 'y'])

# %%
df.head()
# Out:
#           x         y
# 0 -1.783585 -1.481693
# 1 -2.502681 -0.254251
# 2  4.295206 -0.983815
# 3 -1.075423  2.577802
# 4 -1.033518  3.159168

# %%
df.plot()

# %%
df.plot(kind='kde')

# %%
df.plot(kind='hexbin', x='x', y='y', bins=100, cmap='rainbow')

# %% [markdown]
# # Unstructured data

# %% [markdown]
# ### Images

# %%
#pythons imgae Library 
from PIL import Image

# %%
img = Image.open('../data/iss.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x435 at 0x1FFF69CFB88>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
#transforming the image to array
imgarray = np.asarray(img)

# %%
#ndarray means n dimesional  array and its shapes include No od pixels the image has, No of columns and and the No of Colour Channes (Red, Green Blue) 
#RBG
type(imgarray)
# Out:
# numpy.ndarray

# %%
#(435 denotes no of pixels , 640denotes no of columns , 3 and mumber of colour channes rows)
imgarray.shape
# Out:
# (435, 640, 3)

# %%
#Flatten the mage
imgarray.ravel().shape
# Out:
# (835200,)

# %%
#No of dimension we have for the image 
435 * 640 * 3
# Out:
# 835200

# %% [markdown]
# ### Sound

# %%
#use to import sound
from scipy.io import wavfile

# %%
#we load the file into the rate and sound 
rate, snd = wavfile.read(filename='../data/sms.wav')

# %%
from IPython.display import Audio

# %%
Audio(data=snd, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(snd)
# Out:
# 110250

# %%
snd
# Out:
# array([70, 14, 27, ..., 58, 68, 59], dtype=int16)

# %%
plt.plot(snd)

# %%
# shows the frequency of the sounds
_ = plt.specgram(snd, NFFT=1024, Fs=44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# # Data Exploration Exercises

# %% [markdown]
# ## Exercise 1
# - load the dataset: `../data/international-airline-passengers.csv`
# - inspect it using the `.info()` and `.head()` commands
# - use the function [`pd.to_datetime()`](http://pandas.pydata.org/pandas-docs/version/0.20/generated/pandas.to_datetime.html) to change the column type of 'Month' to a datatime type
# - set the index of df to be a datetime index using the column 'Month' and the `df.set_index()` method
# - choose the appropriate plot and display the data
# - choose appropriate scale
# - label the axes

# %%
#Impoet the Neede libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the file 
data =pd.read_csv('../data/international-airline-passengers.csv')
data
# Out:
#        Month  Thousand Passengers
# 0    1949-01                  112
# 1    1949-02                  118
# 2    1949-03                  132
# 3    1949-04                  129
# 4    1949-05                  121
# ..       ...                  ...
# 139  1960-08                  606
# 140  1960-09                  508
# 141  1960-10                  461
# 142  1960-11                  390
# 143  1960-12                  432
#
# [144 rows x 2 columns]

# %%
# We check the info for the data
data_info=data.info()
data_info= pd.DataFrame(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                144 non-null    object
#  1   Thousand Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# we convert the month column to datatime 
from datetime import date, datetime
#import datetime 
data['Month']=pd.to_datetime(data['Month'])
data=data.set_index('Month')
#format='%d%b%Y:%H:%M:%S.%f'

# %%
#We set the index of df to be a datetime index using the column 'Month' 
data
# Out:
#             Thousand Passengers
# Month
# 1949-01-01                  112
# 1949-02-01                  118
# 1949-03-01                  132
# 1949-04-01                  129
# 1949-05-01                  121
# ...                         ...
# 1960-08-01                  606
# 1960-09-01                  508
# 1960-10-01                  461
# 1960-11-01                  390
# 1960-12-01                  432
#
# [144 rows x 1 columns]

# %%
#Here we 
#•choose the appropriate plot and display the data
#•choose appropriate scale
#•label the axes

plt.plot(data)
plt.ylabel('Passengers in Thousand')
plt.xlabel('Year')
plt.title('Passengers Growth Graph')
# Out:
# Text(0.5, 1.0, 'Passengers Growth Graph')

# %% [markdown]
# ##This is the end of Exercise one personla solution

# %% [markdown]
# ## Exercise 2
# - load the dataset: `../data/weight-height.csv`
# - inspect it
# - plot it using a scatter plot with Weight as a function of Height
# - plot the male and female populations with 2 different colors on a new scatter plot
# - remember to label the axes

# %%
#load the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data_weight=pd.read_csv('../data/weight-height.csv')
data_weight
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# We inspect it
data_weight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
data_weight.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
plt. scatter(data_weight['Height'],data_weight['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('A Sccatter Plot Showing Weight as a Function of Height')
# Out:
# Text(0.5, 1.0, 'A Sccatter Plot Showing Weight as a Function of Height')

# %%
# plt. scatter(data_weight['Height'],data_weight['Weight'])
# plt.xlabel('Height')
# plt.ylabel('Weight')
# plt.title('A Sccatter Plot Showing Weight as a Function of Height')
# data_weight.groupby('Gender')['Gender'=='Male'].head(20)

# plt.scatter(data_weight['Height'], data_weight['Weight'], c='blue', cmap='viridis')

# plt.colorbar()

# plt.show()




# •plot the male and female populations with 2 different colors on a new scatter plot
# •label the axes

males = data_weight[data_weight['Gender'] == 'Male']
females = data_weight.query('Gender == "Female"')
fig, ax = plt.subplots()

males.plot(kind='scatter', x='Height', y='Weight',
           ax=ax, color='blue', alpha=0.3,
           title='Male & Female Populations')

females.plot(kind='scatter', x='Height', y='Weight',
             ax=ax, color='red', alpha=0.3)

# %%
plt. scatter(data_weight['Gender'],data_weight['Weight'])

# %%
data_weight.plot(kind='hist',
        bins=100,
        title='Height-Weight distributions',
        normed=True,
        cumulative=True,
        alpha=0.4)
# Out:
# C:\Users\LBAN\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:59: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %%
# data_weight[['Height']].plot(subplots=True,kind='pie',
#                figsize=(5, 5),
#                #explode=[0, 0.15],
#                #labels=['<= 0.1', '> 0.1'],
#                #autopct='%1.1f%%',
#                shadow=True,
#                startangle=90,
#                fontsize=16)
# #show_plot()

# %%
# The end of question 2

# %% [markdown]
# ## Exercise 3
# - plot the histogram of the heights for males and for females on the same plot
# - use alpha to control transparency in the plot comand
# - plot a vertical line at the mean of each population using `plt.axvline()`

# %%
data_weight[data_weight['Gender'] == 'Male']
females = data_weight.query('Gender == "Female"')
fig, ax = plt.subplots()
males['Height'].plot(kind='hist',ax=ax, color='blue', alpha=0.3,bins=40,
                     range=(50, 80),
           title='Height Distribution')

females['Height'].plot(kind='hist', x='Height', y='Weight',
             ax=ax, color='red', alpha=0.4,bins=40,
                     range=(50, 80),)
plt.legend(["Males", "Females"])
plt.axvline(males['Height'].mean(), color='blue', linewidth=2)
plt.axvline(females['Height'].mean(), color='red', linewidth=2)

# %% [markdown]
# ## Exercise 4
# - plot the weights of the males and females using a box plot
# - which one is easier to read?
# - (remember to put in titles, axes and legends)

# %%
# males=data_weight[data_weight['Gender'] == 'Male']
# males=males.drop('Height',axis=1)
# females = data_weight.query('Gender == "Female"')
# females=females.drop('Height',axis=1)
# fig, ax = plt.subplots()
# males.plot(kind='box', color='blue', title='Weight Distribution')
# females.plot(kind='box',color='red')
# plt.legend(["Males", "Females"])
# # # plt.axvline(males['Height'].mean(), color='blue', linewidth=2)
# # # plt.axvline(females['Height'].mean(), color='red', linewidth=2)
data_piv=data_weight.pivot(columns= 'Gender', values= 'Weight')
data_piv.head()
# Out:
# Gender  Female        Male
# 0          NaN  241.893563
# 1          NaN  162.310473
# 2          NaN  212.740856
# 3          NaN  220.042470
# 4          NaN  206.349801

# %%
data_piv.plot(kind='box')
plt.title('Weight Box Plot')
plt.legend(["Males", "Females"])

# %% [markdown]
# ## Exercise 5
# - load the dataset: `../data/titanic-train.csv`
# - learn about scattermatrix here: http://pandas.pydata.org/pandas-docs/stable/visualization.html
# - display the data using a scattermatrix

# %%
titan_train=pd.read_csv('../data/titanic-train.csv')
titan_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titan_train[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(titan_train.drop(columns='PassengerId'), alpha=0.2, figsize=(8, 8), diagonal="hist")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022DD8F3CC48>,
# ...
#       dtype=object)

# %%
plot()
