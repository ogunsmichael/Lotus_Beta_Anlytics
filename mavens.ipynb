# %% [markdown]
# # Importing all libraries needed for the workspace

# %%
#librariy impport
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Reading the csv files

# %%
call_service2016 = pd.read_csv('../data/Calls_for_Service_2016.csv')
call_service2017 = pd.read_csv('../data/Calls_for_Service_2017.csv')
call_service2018 = pd.read_csv('../data/Calls_for_Service_2018.csv')
call_service2019 = pd.read_csv('../data/Calls_for_Service_2019.csv')
call_service2020 = pd.read_csv('../data/Call_for_Service_2020.csv')

# %%
call_service2020.head()
# Out:
#   NOPD_Item Type                        TypeText Priority InitialType  \
# 0  A3472220  22A                      AREA CHECK       1K         22A
# 1  A0000220   21                 COMPLAINT OTHER       1J          21
# 2  A2190820  22A                      AREA CHECK       1K         22A
# 3  A2874820   21                 COMPLAINT OTHER       2A          21
# 4  A2029120  34S  AGGRAVATED BATTERY BY SHOOTING       2C         34S
#
#                   InitialTypeText InitialPriority     MapX    MapY  \
# 0                      AREA CHECK              1K  3688756  528696
# 1                 COMPLAINT OTHER              1J  3668710  533007
# 2                      AREA CHECK              1K  3682445  530709
# 3                 COMPLAINT OTHER              1J  3737616  590067
# 4  AGGRAVATED BATTERY BY SHOOTING              2C  3696210  551411
#
#                TimeCreate  ...              TimeArrive  \
# 0  01/28/2020 01:37:20 AM  ...  01/28/2020 01:37:28 AM
# ...

# %%
call_service2017.head()
# Out:
#   NOPD_Item Type_                 TypeText Priority InitialType  \
# 0  I1379017    21          COMPLAINT OTHER       1H          62
# 1  I1439917   35D  SIMPLE BATTERY DOMESTIC       1A          35
# 2  I1441417    35           SIMPLE BATTERY       1A          35
# 3  I1457517    56   SIMPLE CRIMINAL DAMAGE       1D          56
# 4  I1471317    56   SIMPLE CRIMINAL DAMAGE       0A          56
#
#           InitialTypeText InitialPriority     MapX    MapY  \
# 0         SIMPLE BURGLARY              1E  3732049  562194
# 1          SIMPLE BATTERY              1D  3699789  554869
# 2          SIMPLE BATTERY              1D  3704559  553569
# 3  SIMPLE CRIMINAL DAMAGE              1D  3702537  556077
# 4  SIMPLE CRIMINAL DAMAGE              1D  3695810  557388
#
#                TimeCreate  ...              TimeArrive  \
# 0  09/11/2017 03:35:06 PM  ...  09/13/2017 08:05:17 AM
# 1  09/12/2017 01:25:41 AM  ...  09/13/2017 09:01:55 AM
# ...

# %%
call_service2018.head()
# Out:
#   NOPD_Item Type_             TypeText Priority InitialType  \
# 0  A1964518   67C  THEFT FROM EXTERIOR       1A         62C
# 1  A1213518    21      COMPLAINT OTHER       1J          21
# 2  A0838218    37   AGGRAVATED ASSAULT       1C         103
# 3  B0948918   21P        LOST PROPERTY       0G         21P
# 4  A0609918    24              MEDICAL       2B          29
#
#            InitialTypeText InitialPriority      MapX     MapY  \
# 0  SIMPLE BURGLARY VEHICLE              1G         0        0
# 1          COMPLAINT OTHER              1J         0        0
# 2      DISTURBANCE (OTHER)              2A         0        0
# 3            LOST PROPERTY              0G  37369000  3513814
# 4                    DEATH              1B  37369000  3513814
#
#                TimeCreate  ...              TimeArrive  \
# 0  01/17/2018 04:10:29 PM  ...  01/18/2018 02:34:08 AM
# 1  01/11/2018 12:35:07 AM  ...  01/11/2018 12:35:07 AM
# 2  01/08/2018 01:24:10 AM  ...  01/08/2018 01:28:28 AM
# ...

# %%
call_service2016.head()
# Out:
#   NOPD_Item Type_          TypeText Priority InitialType   InitialTypeText  \
# 0  D0808216    24           MEDICAL       2B          21   COMPLAINT OTHER
# 1  D0812216    18  TRAFFIC INCIDENT       1H          18  TRAFFIC INCIDENT
# 2  D0812716  103M    MENTAL PATIENT       2A        103M    MENTAL PATIENT
# 3  I3355216    21   COMPLAINT OTHER       1H          21   COMPLAINT OTHER
# 4  D0816216    24           MEDICAL       2B          24           MEDICAL
#
#   InitialPriority      MapX     MapY              TimeCreate  ...  \
# 0              2A  37369000  3513814  04/07/2016 09:24:16 PM  ...
# 1              1H  37369000  3513814  04/07/2016 09:56:49 PM  ...
# 2              2A  37369000  3513814  04/07/2016 10:00:09 PM  ...
# 3              1H         0        0  09/30/2016 02:06:54 AM  ...
# 4              2B  37369000  3513814  04/07/2016 10:48:36 PM  ...
#
#                TimeArrive              TimeClosed Disposition  \
# ...

# %%
call_service2019.head()
# Out:
#   NOPD_Item  Type                     TypeText Priority     MapX    MapY  \
# 0  E3696819   21P                LOST PROPERTY       0G  3682079  532392
# 1  E3711919   34D  AGGRAVATED BATTERY DOMESTIC       2C  3674751  525920
# 2  E3721919   21P                LOST PROPERTY       0G  3681704  531945
# 3  E3724019  103D         DOMESTIC DISTURBANCE       2C  3699162  557853
# 4  E3735719   62C      SIMPLE BURGLARY VEHICLE       1G  3727938  560667
#
#                TimeCreate            TimeDispatch             TimeArrival  \
# 0  05/26/2019 05:08:29 AM  05/26/2019 05:08:29 AM  05/26/2019 05:08:29 AM
# 1  05/26/2019 09:10:51 AM  05/26/2019 09:12:32 AM  05/26/2019 09:21:11 AM
# 2  05/26/2019 10:47:30 AM  05/26/2019 03:46:05 PM  05/26/2019 03:46:10 PM
# 3  05/26/2019 11:12:23 AM  05/26/2019 11:18:05 AM  05/26/2019 11:39:08 AM
# 4  05/26/2019 01:36:51 PM  05/26/2019 05:37:42 PM  05/26/2019 05:37:47 PM
#
#                TimeClosed  ...   DispositionText InitialType  \
# ...

# %% [markdown]
# # What fraction  by percentage of calls with most common type?

# %%
High__calltype=call_service2020['Type'].value_counts().max()
Percentage_fraction = (High__calltype/432892)*100
Percentage_fraction
# Out:
# 23.926753093150253

# %% [markdown]
# # For this and the remaining questions, consider data from all five years. As you combine the data, you will notice that duplicate item numbers appear across years, for calls whose resolution spans the new year. Remove these duplicate rows. How many duplicate rows were removed?

# %% [markdown]
# # Concatinating all the Data Frame using .concat()

# %%
call_service = pd.concat([call_service2016, call_service2017, call_service2018, call_service2019, call_service2020])
pd.set_option('display.max_columns', None)
call_service.head()
# Out:
#   NOPD_Item Type_          TypeText Priority InitialType   InitialTypeText  \
# 0  D0808216    24           MEDICAL       2B          21   COMPLAINT OTHER
# 1  D0812216    18  TRAFFIC INCIDENT       1H          18  TRAFFIC INCIDENT
# 2  D0812716  103M    MENTAL PATIENT       2A        103M    MENTAL PATIENT
# 3  I3355216    21   COMPLAINT OTHER       1H          21   COMPLAINT OTHER
# 4  D0816216    24           MEDICAL       2B          24           MEDICAL
#
#   InitialPriority      MapX     MapY              TimeCreate  \
# 0              2A  37369000  3513814  04/07/2016 09:24:16 PM
# 1              1H  37369000  3513814  04/07/2016 09:56:49 PM
# 2              2A  37369000  3513814  04/07/2016 10:00:09 PM
# 3              1H         0        0  09/30/2016 02:06:54 AM
# 4              2B  37369000  3513814  04/07/2016 10:48:36 PM
#
#              TimeDispatch              TimeArrive              TimeClosed  \
# ...

# %% [markdown]
# # Calculating the mean(Average) of the time of response using the time a dispatch was made to the

# %%
call_service['TimeDispatch'] = pd.to_datetime(call_service['TimeDispatch'], infer_datetime_format=True)

# now for your answer, get the average of the timestamp column
print(call_service['TimeDispatch'].mean())
# Out:
# 2018-09-12 00:54:28.027160320

# %%
call_service['TimeArrive'] = pd.to_datetime(call_service['TimeArrive'], infer_datetime_format=True)

# now for your answer, get the average of the timestamp column
print(call_service['TimeArrive'].mean())
# Out:
# 2018-05-04 12:40:14.774120448

# %%
Mean_Aggregate = (call_service['TimeDispatch'].mean() - call_service['TimeArrive'].mean())/2
Mean_Aggregate
# Out:
# Timedelta('65 days 06:07:06.626519')

# %% [markdown]
# # The NINe District are counted by

# %%
#District Value counts
call_dis=call_service['PoliceDistrict'].value_counts()
call_dis
# Out:
# 3    381985
# 1    305563
# 7    292529
# 8    288646
# 6    271636
# 2    235267
# 5    231835
# 4    207336
# 0     14504
# Name: PoliceDistrict, dtype: int64

# %%
# since the distric with the highest count is the district 3 anfd the mean of the lowest
# Then we find the mean of the hihest distric and that of the lowest district 
# We then find their differences

# %%
group_dis=call_service.groupby('PoliceDistrict')[[ 'TimeDispatch','TimeArrive']]
group_dis.head()
# Out:
#           TimeDispatch          TimeArrive
# 0  2016-04-07 21:26:29 2016-04-07 21:37:10
# 1                  NaT 2016-04-07 21:56:49
# 2  2016-04-07 22:03:15 2016-04-07 22:12:58
# 3  2016-09-30 02:07:09 2016-09-30 02:06:54
# 4                  NaT 2016-04-07 22:48:36
# 5  2016-09-30 03:15:13 2016-09-30 03:17:21
# 6  2016-09-30 04:18:21 2016-09-30 04:20:13
# 7  2016-04-08 01:15:54 2016-04-08 01:20:37
# 8  2016-09-30 04:54:53 2016-09-30 04:58:01
# 9                  NaT 2016-04-08 13:44:38
# 10 2016-04-08 00:18:31 2016-04-08 00:22:05
# 11                 NaT 2016-04-08 00:25:05
# 12 2016-09-30 06:53:14 2016-09-30 06:26:33
# 13 2016-09-30 12:55:08 2016-09-30 13:01:37
# 14 2016-04-08 04:00:08 2016-04-08 01:40:17
# 15 2016-04-08 02:18:08                 NaT
# 16 2016-09-30 08:46:22 2016-09-30 08:46:53
# 17                 NaT 2016-04-08 02:40:07
# 18 2016-04-08 03:08:59 2016-04-08 03:11:32
# 19 2016-09-30 10:03:57 2016-09-30 10:15:03
# 20 2016-09-30 09:07:33 2016-09-30 09:08:31
# ...

# %% [markdown]
# # Time count of by district

# %%
group_dis.count()
# Out:
#                 TimeDispatch  TimeArrive
# PoliceDistrict
# 0                      12815       10547
# 1                     248734      197627
# 2                     201780      157755
# 3                     326716      247917
# 4                     177764      141728
# 5                     202349      153321
# 6                     230049      187798
# 7                     247007      171471
# 8                     233698      181387

# %%
# call_service_dist=call_service.groupby('TimeDispatch')[['PoliceDistrict'='3','TimeDispatch']]

# %%
# result = call_service.groupby('PoliceDistrict').agg({'TimeArrive': ['mean', 'min', 'max']})

# %%
Dist_3=group_dis.get_group(3)
Dist_3
# Out:
#               TimeDispatch          TimeArrive
# 30     2016-04-08 08:46:28 2016-04-08 09:02:54
# 37     2016-03-15 08:50:43 2016-03-15 08:51:10
# 52     2016-04-08 12:36:35 2016-04-08 12:38:27
# 61     2016-09-30 16:59:40 2016-09-30 17:08:50
# 80                     NaT                 NaT
# ...                    ...                 ...
# 432880 2020-12-31 03:05:44 2020-12-31 03:05:44
# 432887 2020-12-31 03:19:51 2020-12-31 03:19:51
# 432888 2020-12-31 18:48:47                 NaT
# 432890 2020-12-31 21:24:31 2020-12-31 21:58:44
# 432891 2020-12-31 20:14:12 2020-12-31 20:23:38
#
# [381985 rows x 2 columns]

# %%
# def avg_datetime(series):
#   dt_min = series.min()
#   deltas = [x-dt_min for x in series]

Dist_3.describe()
# Out:
#                TimeDispatch           TimeArrive
# count                326716               247917
# unique               325590               247503
# top     2020-03-31 08:14:32  2016-02-28 20:49:01
# freq                      4                    4
# first   2016-01-01 00:21:24  2016-01-01 00:19:37
# last    2021-01-01 02:04:32  2021-01-01 02:06:03

# %%
# Dist_3.sum() / len(Dist_3)
# group_dis.sum()
import math

# %%
call_service.groupby('PoliceDistrict')['TimeArrive'].get_group(3).mean()
# Out:
# Timestamp('2018-06-20 09:51:46.316257536')

# %%
call_service.groupby('PoliceDistrict')['TimeDispatch'].get_group(3).mean()
# Out:
# Timestamp('2018-10-07 12:59:16.548503552')

# %%
dist_3_agg=  (call_service.groupby('PoliceDistrict')['TimeArrive'].get_group(3).mean()-call_service.groupby('PoliceDistrict')['TimeDispatch'].get_group(3).mean())/2

# %%
dist_3_agg
# Out:
# Timedelta('-55 days +10:26:14.883876')

# %%
call_service.groupby('PoliceDistrict')['TimeArrive'].get_group(0).mean()
# Out:
# Timestamp('2019-05-14 15:04:24.285484288')

# %%
call_service.groupby('PoliceDistrict')['TimeDispatch'].get_group(0).mean()
# Out:
# Timestamp('2019-07-17 06:35:32.466880')

# %%
dist_0_agg=(call_service.groupby('PoliceDistrict')['TimeArrive'].get_group(0).mean()-call_service.groupby('PoliceDistrict')['TimeDispatch'].get_group(0).mean())/2

# %%
dist_0_agg
# Out:
# Timedelta('-32 days +04:14:25.909302')

# %%
Min_Max_Agg=dist_3_agg-dist_0_agg
Min_Max_Agg
# Out:
# Timedelta('-23 days +06:11:48.974574')

# %%
call_service.describe().transpose()
# Out:
#                     count          mean           std  min        25%  \
# MapX            2229301.0  4.965280e+06  6.477118e+06  0.0  3673351.0
# MapY            2229301.0  6.500032e+05  5.733271e+05  0.0   528612.0
# PoliceDistrict  2229301.0  4.439624e+00  2.362612e+00  0.0        3.0
#
#                       50%        75%         max
# MapX            3681425.0  3693448.0  37369000.0
# MapY             535239.0   548775.0  25794980.0
# PoliceDistrict        4.0        7.0         8.0

# %%
call_service['TimeArrive'].dt.strftime('%B')
# Out:
# 0             April
# 1             April
# 2             April
# 3         September
# 4             April
#             ...
# 432887     December
# 432888          NaN
# 432889     December
# 432890     December
# 432891     December
# Name: TimeArrive, Length: 2229301, dtype: object
